# %% [markdown]
# TD : Collecte des Données en Python pour le
# Traitement du Langage Naturel (NLP)

# %% [markdown]
# 1 Pour commencer

# %% [markdown]
# 1. Quelles sont les principales sources de données textuelles pour le NLP ?
# Les principales sources sont les documents texte, les transcriptions de discours, les publications sur les réseaux sociaux, les avis clients , etc.
# 2. Pourquoi la collecte de données est-elle essentielle pour le NLP ?
# C'est nécessaire pour entraîner les modèles, améliorer leur performance.

# %% [markdown]
# 2 Extraction de données à partir d’une API

# %% [markdown]
# La première étape est d'importer la bibliothèque requests qui nous permettra à partir de NewsAPI de récollecter des informations sur des articles sur un thème choisi (en choisissant la période, en classant par ordre de popularité).

# %%
import requests

url = ('https://newsapi.org/v2/everything?'
       'q=Spider Man&'
       'from=2024'
       'sortBy=popularity&'
       'apiKey=af9b1c16ddfa4c17a8c38de16d7dfbc3')

response = requests.get(url)

print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 3212, 'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'}, 'author': 'Germain Lussier', 'title': 'The Larger Sony Spider-Man Universe May End This Week', 'description': 'Kraven the Hunter might be the last Spider-Man film without Spider-Man for some time.', 'url': 'https://gizmodo.com/sony-spiderman-universe-dead-kraven-the-hunter-tom-holland-2000536639', 'urlToImage': 'https://gizmodo.com/app/uploads/2024/12/spiderman-across-spiderverse-poster.jpg', 'publishedAt': '2024-12-10T17:50:13Z', 'content': 'Morbin’ time may finally be over. No more researching spiders in the Amazon. Venom has been stung. And Kraven is, apparently, no longer what Sony is cravin’. This week marks the release of Kraven the… [+2194 chars]'}, {'source': {'id': None, 'name': 'Gizmodo.com'}, 'author': 'James Whitbrook', 'title': 'The Comic Book History Behind Kraven‘s Wildest Spider-Man Connection', 'description': "We may never know where Sony could've gone in still trying 
# ...

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 3212,
#  'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Germain Lussier',
#    'title': 'The Larger Sony Spider-Man Universe May End This Week',
#    'description': 'Kraven the Hunter might be the last Spider-Man film without Spider-Man for some time.',
#    'url': 'https://gizmodo.com/sony-spiderman-universe-dead-kraven-the-hunter-tom-holland-2000536639',
#    'urlToImage': 'https://gizmodo.com/app/uploads/2024/12/spiderman-across-spiderverse-poster.jpg',
#    'publishedAt': '2024-12-10T17:50:13Z',
#    'content': 'Morbin’ time may finally be over. No more researching spiders in the Amazon. Venom has been stung. And Kraven is, apparently, no longer what Sony is cravin’. This week marks the release of Kraven the… [+2194 chars]'},
#   {'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'James Whitbrook',
#    'title': 'The Comic Book History Behind Kraven‘s Wildest Spider-Man Connection',
# ...

# %% [markdown]
# 3 Web scraping de textes

# %% [markdown]
# Ensuite, il est nécessaire d'installer BeautifulSoup pour ensuite importer la bibliothèque associée qui nous permettra d'extraire des données textuelles.

# %%
pip install beautifulsoup4
# Out:
# ...
#   Using cached beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached soupsieve-2.6-py3-none-any.whl.metadata (4.6 kB)
# Using cached beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
# Using cached soupsieve-2.6-py3-none-any.whl (36 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import csv
import pandas as pd
import requests
from bs4 import BeautifulSoup

url = ('https://www.worldometers.info/world-population/population-by-country/')
response = requests.get(url)

# %%
print(reponse)
# Out:
# <Response [403]>

# %%
pip install lxml
# Out:
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 5.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 3.4/3.8 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 9.5 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Voici ensuite une table html obtenue à partir d'un lien http.

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# URL de la page avec les tables HTML
url = 'https://www.worldometers.info/world-population/population-by-country/'

# Faire une requête GET pour récupérer le contenu de la page
req = requests.get(url)

# Créer l'objet BeautifulSoup avec l'analyseur 'html.parser'
soup = BeautifulSoup(req.text, 'html.parser')

# Trouver toutes les tables HTML
tables = soup.find_all("table")

# Vérifier si des tables ont été trouvées
if tables:
    # Extraire la première table
    data = tables[0]
    df_population = pd.read_html(str(data))[0]
    print(df_population.head())
else:
    print("Aucune table trouvée.")
# Out:
# C:\Users\SCD UM\AppData\Local\Temp\ipykernel_6428\688984249.py:21: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df_population = pd.read_html(str(data))[0]
#    # Country (or dependency)  Population  (2024) Yearly  Change  Net  Change  \
# 0  1                   India          1450935791         0.89 %     12866195
# 1  2                   China          1419321278        -0.23 %     -3263655
# 2  3           United States           345426571         0.57 %      1949236
# 3  4               Indonesia           283487931         0.82 %      2297864
# 4  5                Pakistan           251269164         1.52 %      3764669
#
#    Density  (P/Km²)  Land Area  (Km²)  Migrants  (net)  Fert.  Rate  \
# 0               488           2973190          -630830          2.0
# 1               151           9388211          -318992          1.0
# ...
